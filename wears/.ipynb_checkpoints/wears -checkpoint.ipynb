# %%
import pandas as pd 
import numpy as np

# %%
from bs4 import BeautifulSoup as soup
from urllib.request import urlopen as uReq
# print(dir(soup))

# %%
site = "https://www.flipkart.com/clothing-and-accessories/topwear/pr?sid=clo%2Cash&otracker=categorytree&p%5B%5D=facets.ideal_for%255B%255D%3DMen&otracker=nmenu_sub_Men_0_Top%20wear"
uClient = uReq(site)
page= uClient.read()
uClient.close()

# %%
work = soup(page, "html.parser")
div = work.find_all("div", { "class": "_1YokD2 _2GoDe3 col-12-12"})
len(div)
# Out:
# 1

# %%
div = work.find_all("div", { "class": "_1xHGtK _373qXS"})
len(div)
# Out:
# 40

# %%
name  = work.find_all("div", { "class": "_2WkVRV"})
description  = work.find_all("a", { "class": "IRpwTa"})
discount  = work.find_all("div", { "class": "_3Ay6Sb"})
price = work.find_all("div", { "class": "_30jeq3"})

# %%
Products = []
Price = []
Description = []
Discount = []

for i in name:
    p = i.text
    Products.append(p)

for i in price:
    pp= i.text
    Price.append(pp)
    
for i in description:
    des = i.text
    Description.append(des)
    
for i in discount:
    dis = i.text
    Discount.append(dis)

# %%
df = pd.DataFrame({"Products":Products,"Description":Description, "Price":Price,"Discount":Discount})
df.index = pd.RangeIndex(start=1, stop=41, step=1)
df
# Out:
#                  Products                                        Description  \
# 1   HRX by Hrithik Roshan                  Solid Men Polo Neck Black T-Shirt
# 2                Roadster               Men Regular Fit Printed Casual Shirt
# 3               Eyebogler           Self Design Men Round Neck Black T-Shirt
# 4                   TRIPR      Solid Men Mandarin Collar Grey, Black T-Shirt
# 5            Dennis Lingo        Men Slim Fit Solid Slim Collar Casual Shirt
# 6            THE EG STORE             Color Block Men Round Neck Red T-Shirt
# 7               Eyebogler   Striped Men Polo Neck White, Blue, Green T-Shirt
# 8              HIGHLANDER      Men Slim Fit Solid Spread Collar Casual Shirt
# 9            Dennis Lingo        Men Slim Fit Solid Slim Collar Casual Shirt
# 10            Seven Rocks                Striped Men Polo Neck White T-Shirt
# 11             HIGHLANDER  Men Slim Fit Printed Cut Away Collar Casual Shirt
# 12             HIGHLANDER    Men Slim Fit Printed Spread Collar Casual Shirt
# 13                  BLIVE    Solid Men Henley Neck Maroon, Dark Blue T-Shirt
# 14                  TRIPR      Color Block Men Round Neck Black, Red T-Shirt
# 15                  Surhi                Men Slim Fit Checkered Casual Shirt
# 16                   UZee           Striped Men Round Neck Dark Blue T-Shirt
# 17             HIGHLANDER  Men Slim Fit Checkered Spread Collar Casual Shirt
# 18             HIGHLANDER  Men Slim Fit Printed Cut Away Collar Casual Shirt
# 19              Eyebogler       Solid Men Collared Neck White, Black T-Shirt
# 20                   Reya            Solid Men Mandarin Collar Black T-Shirt
# 21             HIGHLANDER  Men Slim Fit Striped Mandarin Collar Casual Shirt
# 22  HRX by Hrithik Roshan                 Solid Men Round Neck Black T-Shirt
# 23                    FTX  Solid Men Round Neck Black, Dark Blue, Grey T-...
# 24                  BLIVE        Striped Men Round Neck Maroon, Grey T-Shirt
# 25                  Pepzo   Men Regular Fit Solid Spread Collar Casual Shirt
# 26              Eyebogler          Color Block Men Round Neck Yellow T-Shirt
# 27                  KETCH  Men Slim Fit Printed Cut Away Collar Casual Shirt
# 28             HIGHLANDER                    Men Slim Fit Solid Casual Shirt
# 29                  TRIPR     Solid Men Mandarin Collar Brown, Black T-Shirt
# 30                   Reya                Striped Men Round Neck Blue T-Shirt
# 31              METRONAUT  Men Regular Fit Checkered Spread Collar Casual...
# 32              METRONAUT    Graphic Print Men Round Neck Dark Green T-Shirt
# 33                   Reya             Solid Men Mandarin Collar Blue T-Shirt
# 34             FastColors          Solid Men Round Neck Black, White T-Shirt
# 35           THE EG STORE  Color Block Men Round Neck Grey, Red, Black T-...
# 36                HELMONT         Striped Men Hooded Neck Red, Black T-Shirt
# 37             HIGHLANDER    Men Slim Fit Printed Spread Collar Casual Shirt
# 38                  KETCH    Men Slim Fit Solid Mandarin Collar Casual Shirt
# 39           Trends Tower                Solid Men Round Neck Maroon T-Shirt
# 40                   AUSK  Color Block Men Round Neck White, Blue, Grey T...
#
#    Price Discount
# 1   ₹493  62% off
# 2   ₹699  53% off
# 3   ₹299  76% off
# 4   ₹299  85% off
# 5   ₹500  72% off
# 6   ₹299  62% off
# 7   ₹399  69% off
# 8   ₹499  50% off
# 9   ₹500  72% off
# 10  ₹280  78% off
# 11  ₹384  65% off
# 12  ₹428  61% off
# 13  ₹399  86% off
# 14  ₹265  86% off
# 15  ₹399  80% off
# 16  ₹227  82% off
# 17  ₹449  55% off
# 18  ₹503  52% off
# 19  ₹299  76% off
# 20  ₹290  80% off
# 21  ₹419  65% off
# 22  ₹345  50% off
# 23  ₹399  60% off
# 24  ₹219  78% off
# 25  ₹345  82% off
# 26  ₹299  76% off
# 27  ₹419  70% off
# 28  ₹428  61% off
# 29  ₹299  85% off
# 30  ₹298  80% off
# 31  ₹509  70% off
# 32  ₹375  55% off
# 33  ₹290  80% off
# 34  ₹279  86% off
# 35  ₹245  69% off
# 36  ₹197  80% off
# 37  ₹425  63% off
# 38  ₹437  65% off
# 39  ₹299  62% off
# 40  ₹299  70% off

# %%
# df.to_csv("wears.csv")
# df.to_csv ("C:\\Users\\user\\Desktop\\Web Scrapping\\ass\\wears.csv")

# %%
# import matplotlib
# pyplot is a function in matplotlib, which can as well be written as matplotlib.pyplot
from matplotlib import pyplot as plt
